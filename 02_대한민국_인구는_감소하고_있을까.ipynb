# %% [markdown]
# <a href="https://colab.research.google.com/github/ahnjonghyunn/ABC/blob/main/02_%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD_%EC%9D%B8%EA%B5%AC%EB%8A%94_%EA%B0%90%EC%86%8C%ED%95%98%EA%B3%A0_%EC%9E%88%EC%9D%84%EA%B9%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 준비하기

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv('/content/201212_202112_주민등록인구및세대현황_연간.csv',encoding='cp949')
df.head()
# Out:
#     행정구역  2012년_총인구수  2012년_세대수  2012년_남자 인구수  2012년_여자 인구수  2013년_총인구수  \
# 0  서울특별시    10195318    4177970       5041336       5153982    10143645
# 1  부산광역시     3538484    1389526       1754479       1784005     3527635
# 2  대구광역시     2505644     948652       1249320       1256324     2501588
# 3  인천광역시     2843981    1097491       1431593       1412388     2879782
# 4  광주광역시     1469216     555538        728406        740810     1472910
#
#    2013년_세대수  2013년_남자 인구수  2013년_여자 인구수  2014년_총인구수  ...  2019년_남자 인구수  \
# 0    4182351       5007869       5135776    10103233  ...       4744059
# 1    1404663       1747000       1780635     3519401  ...       1675417
# 2     960265       1246071       1255517     2493264  ...       1205286
# 3    1118988       1448835       1430947     2902608  ...       1482249
# 4     563599        730216        742694     1475884  ...        720740
#
#    2019년_여자 인구수  2020년_총인구수  2020년_세대수  2020년_남자 인구수  2020년_여자 인구수  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역          17 non-null     object
#  1   2012년_총인구수    17 non-null     int64
#  2   2012년_세대수     17 non-null     int64
#  3   2012년_남자 인구수  17 non-null     int64
#  4   2012년_여자 인구수  17 non-null     int64
#  5   2013년_총인구수    17 non-null     int64
#  6   2013년_세대수     17 non-null     int64
#  7   2013년_남자 인구수  17 non-null     int64
#  8   2013년_여자 인구수  17 non-null     int64
#  9   2014년_총인구수    17 non-null     int64
#  10  2014년_세대수     17 non-null     int64
#  11  2014년_남자 인구수  17 non-null     int64
#  12  2014년_여자 인구수  17 non-null     int64
#  13  2015년_총인구수    17 non-null     int64
#  14  2015년_세대수     17 non-null     int64
#  15  2015년_남자 인구수  17 non-null     int64
#  16  2015년_여자 인구수  17 non-null     int64
#  17  2016년_총인구수    17 non-null     int64
# ...

# %% [markdown]
# 데이터 전처리

# %%
population = df.loc[:,['행정구역',
                       '2012년_총인구수',
                       '2013년_총인구수',
                       '2014년_총인구수',
                       '2015년_총인구수',
                       '2016년_총인구수',
                       '2017년_총인구수',
                       '2018년_총인구수',
                       '2019년_총인구수',
                       '2020년_총인구수',
                       '2021년_총인구수']]

population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역        17 non-null     object
#  1   2012년_총인구수  17 non-null     int64
#  2   2013년_총인구수  17 non-null     int64
#  3   2014년_총인구수  17 non-null     int64
#  4   2015년_총인구수  17 non-null     int64
#  5   2016년_총인구수  17 non-null     int64
#  6   2017년_총인구수  17 non-null     int64
#  7   2018년_총인구수  17 non-null     int64
#  8   2019년_총인구수  17 non-null     int64
#  9   2020년_총인구수  17 non-null     int64
#  10  2021년_총인구수  17 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 1.6+ KB

# %%
population.T
# Out:
#                   0        1        2        3        4        5        6   \
# 행정구역           서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시    울산광역시
# 2012년_총인구수  10195318  3538484  2505644  2843981  1469216  1524583  1147256
# 2013년_총인구수  10143645  3527635  2501588  2879782  1472910  1532811  1156480
# 2014년_총인구수  10103233  3519401  2493264  2902608  1475884  1531809  1166377
# 2015년_총인구수  10022181  3513777  2487829  2925815  1472199  1518775  1173534
# 2016년_총인구수   9930616  3498529  2484557  2943069  1469214  1514370  1172304
# 2017년_총인구수   9857426  3470653  2475231  2948542  1463770  1502227  1165132
# 2018년_총인구수   9765623  3441453  2461769  2954642  1459336  1489936  1155623
# 2019년_총인구수   9729107  3413841  2438031  2957026  1456468  1474870  1148019
# 2020년_총인구수   9668465  3391946  2418346  2942828  1450062  1463882  1136017
# 2021년_총인구수   9509458  3350380  2385412  2948375  1441611  1452251  1121592
#
# ...

# %%
df=population.set_index('행정구역').T
df
# Out:
# 행정구역           서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시    울산광역시  \
# 2012년_총인구수  10195318  3538484  2505644  2843981  1469216  1524583  1147256
# 2013년_총인구수  10143645  3527635  2501588  2879782  1472910  1532811  1156480
# 2014년_총인구수  10103233  3519401  2493264  2902608  1475884  1531809  1166377
# 2015년_총인구수  10022181  3513777  2487829  2925815  1472199  1518775  1173534
# 2016년_총인구수   9930616  3498529  2484557  2943069  1469214  1514370  1172304
# 2017년_총인구수   9857426  3470653  2475231  2948542  1463770  1502227  1165132
# 2018년_총인구수   9765623  3441453  2461769  2954642  1459336  1489936  1155623
# 2019년_총인구수   9729107  3413841  2438031  2957026  1456468  1474870  1148019
# 2020년_총인구수   9668465  3391946  2418346  2942828  1450062  1463882  1136017
# 2021년_총인구수   9509458  3350380  2385412  2948375  1441611  1452251  1121592
#
# 행정구역        세종특별자치시       경기도      강원도     충청북도     충청남도     전라북도     전라남도  \
# ...

# %%
df.reset_index(drop=False)
# Out:
# 행정구역       index     서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시  \
# 0     2012년_총인구수  10195318  3538484  2505644  2843981  1469216  1524583
# 1     2013년_총인구수  10143645  3527635  2501588  2879782  1472910  1532811
# 2     2014년_총인구수  10103233  3519401  2493264  2902608  1475884  1531809
# 3     2015년_총인구수  10022181  3513777  2487829  2925815  1472199  1518775
# 4     2016년_총인구수   9930616  3498529  2484557  2943069  1469214  1514370
# 5     2017년_총인구수   9857426  3470653  2475231  2948542  1463770  1502227
# 6     2018년_총인구수   9765623  3441453  2461769  2954642  1459336  1489936
# 7     2019년_총인구수   9729107  3413841  2438031  2957026  1456468  1474870
# 8     2020년_총인구수   9668465  3391946  2418346  2942828  1450062  1463882
# 9     2021년_총인구수   9509458  3350380  2385412  2948375  1441611  1452251
#
# 행정구역    울산광역시  세종특별자치시       경기도      강원도     충청북도     충청남도     전라북도     전라남도  \
# 0     1147256   113117  12093299  1538630  1565628  2028777  1873341  1909618
# ...

# %%
df.to_csv('/content/df.csv',encoding="cp949")

# %%
df= pd.read_csv('/content/df.csv',encoding="cp949")
df
# Out:
#    Unnamed: 0     서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시    울산광역시  \
# 0  2012년_총인구수  10195318  3538484  2505644  2843981  1469216  1524583  1147256
# 1  2013년_총인구수  10143645  3527635  2501588  2879782  1472910  1532811  1156480
# 2  2014년_총인구수  10103233  3519401  2493264  2902608  1475884  1531809  1166377
# 3  2015년_총인구수  10022181  3513777  2487829  2925815  1472199  1518775  1173534
# 4  2016년_총인구수   9930616  3498529  2484557  2943069  1469214  1514370  1172304
# 5  2017년_총인구수   9857426  3470653  2475231  2948542  1463770  1502227  1165132
# 6  2018년_총인구수   9765623  3441453  2461769  2954642  1459336  1489936  1155623
# 7  2019년_총인구수   9729107  3413841  2438031  2957026  1456468  1474870  1148019
# 8  2020년_총인구수   9668465  3391946  2418346  2942828  1450062  1463882  1136017
# 9  2021년_총인구수   9509458  3350380  2385412  2948375  1441611  1452251  1121592
#
#    세종특별자치시       경기도      강원도     충청북도     충청남도     전라북도     전라남도     경상북도  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'],
#       dtype='object')

# %%
df.columns=['연도별 총인구수', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
       '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
       '경상북도', '경상남도', '제주특별자치도']
df
# Out:
#      연도별 총인구수     서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시    울산광역시  \
# 0  2012년_총인구수  10195318  3538484  2505644  2843981  1469216  1524583  1147256
# 1  2013년_총인구수  10143645  3527635  2501588  2879782  1472910  1532811  1156480
# 2  2014년_총인구수  10103233  3519401  2493264  2902608  1475884  1531809  1166377
# 3  2015년_총인구수  10022181  3513777  2487829  2925815  1472199  1518775  1173534
# 4  2016년_총인구수   9930616  3498529  2484557  2943069  1469214  1514370  1172304
# 5  2017년_총인구수   9857426  3470653  2475231  2948542  1463770  1502227  1165132
# 6  2018년_총인구수   9765623  3441453  2461769  2954642  1459336  1489936  1155623
# 7  2019년_총인구수   9729107  3413841  2438031  2957026  1456468  1474870  1148019
# 8  2020년_총인구수   9668465  3391946  2418346  2942828  1450062  1463882  1136017
# 9  2021년_총인구수   9509458  3350380  2385412  2948375  1441611  1452251  1121592
#
#    세종특별자치시       경기도      강원도     충청북도     충청남도     전라북도     전라남도     경상북도  \
# ...

# %% [markdown]
# 데이터 시각화

# %%
fig=go.Figure()

fig.add_trace(go.Scatter(x=df['연도별 총인구수'],
                         y=df['서울특별시'],name='서울특별시'))
fig.add_trace(go.Scatter(x=df['연도별 총인구수'],
                         y=df['대전광역시'],name='대전광역시'))
fig.add_trace(go.Scatter(x=df['연도별 총인구수'],
                         y=df['세종특별자치시'],name='세종특별자치시'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.add_trace(go.Scatter(x=df['연도별 총인구수'],
                         y=df['경기도'],name='경기도'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['서울특별시']))
fig.update_layout(title='서울특별시 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['충청남도']))
fig.update_layout(title='충청남도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['충청북도']))
fig.update_layout(title='충청북도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['제주특별자치도']))
fig.update_layout(title='제주특별자치도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['대전광역시']))
fig.update_layout(title='대전광역시 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['경기도']))
fig.update_layout(title='경기도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['부산광역시']))
fig.update_layout(title='부산광역시 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
figf.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['경상남도']))
fig.update_layout(title='경상남도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['강원도']))
fig.update_layout(title='강원도 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['인천광역시']))
fig.update_layout(title='인천광역시 2012년~2021년 총인구수')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['인천광역시'],name="인천광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['서울특별시'],name="서울특별시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['부산광역시'],name="부산광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['대구광역시'],name="대구광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['광주광역시'],name="광주광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['대전광역시'],name="대전광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['울산광역시'],name="울산광역시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['세종특별자치시'],name="세종특별자치시"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['경기도'],name="경기도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['강원도'],name="강원도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['충청북도'],name="충청북도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['충청남도'],name="충청남도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['전라북도'],name="전라북도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['전라남도'],name="전라남도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['경상북도'],name="경상북도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['경상남도'],name="경상남도"))
fig.add_trace(go.Scatter(
    x=df['연도별 총인구수'], y=df['제주특별자치도'],name="제주특별자치도"))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
